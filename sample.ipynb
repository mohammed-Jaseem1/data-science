# %%
a=10
b=5
c=a+b
print("ARITHMETIC OPERATIONS")
print("SUM IS:",c)
d=a-b
print("DIFFERENCE IS :",d)
e=a/d
print("WHEN DIVIDED:",e)
f=a*b
print("WHEN MULTIPLIED",f)
g=a%b
print("MOD VALUE IS:",g)



print("LIST OPERTIONS")
l1=[1,2,3,4]
l2=[3,4,8,9]
sum=0
print(l1)
print(l2)
for i in l1:
    sum=sum+i
    print(i)
print("list contents are:",i)  
print("the sum is",sum)
l1.append(6)
print("list 1 after adding 6 to it:",l1)
l2.remove(3)
print("list 2 after removing value 3",l2)
l1.pop(4)
print("list 1 after popping the value in 4th index",l1)
print("elements in the given range are:",l1[:3])



print("SET OPERATIONS:")
s1={"tulip","cheesecake","rabbit"}
s1.add("data science")
print("after adding an element",s1)
s1.remove("rabbit")
print("after removing an element:",s1)



print("DICTIONARY OPERATIONS:")
d1={1:"shifana",2:"nahyan",3:"aswin"}
print("the dictionary is:",d1)
print("DISPLAYING THE VALUE OF A CORRESPONDING KEY")
print(d1[1])
print(4 in d1)
d1[4]='virat kohli'
print(d1)

print("BOOLEAN OPERATIONS:")
t,f=True,False
print(t and f)
print(t or f)
print(not t)



print("STRING MANIPULATIONS")
s="cheesecake"
print("the given string is:",s)
print("the length of the given string is:",len(s))
print("the charcter in s[0]:",s[0])
print("the character in s[-3]",s[-3])
print("to change all the characters to uppercase:",s.upper())
print("to change all the characters to uppercase:",s.upper())
print("to dispaly all the characters in a specific range:",s[2:7])
print("string concatenation:")
print("data" + " " "science")
print("string replication:")
print("hi " * 3)
# Out:
# ARITHMETIC OPERATIONS
# SUM IS: 15
# DIFFERENCE IS : 5
# WHEN DIVIDED: 2.0
# WHEN MULTIPLIED 50
# MOD VALUE IS: 0
# LIST OPERTIONS
# [1, 2, 3, 4]
# [3, 4, 8, 9]
# 1
# 2
# 3
# 4
# list contents are: 4
# the sum is 10
# list 1 after adding 6 to it: [1, 2, 3, 4, 6]
# list 2 after removing value 3 [4, 8, 9]
# list 1 after popping the value in 4th index [1, 2, 3, 4]
# elements in the given range are: [1, 2, 3]
# SET OPERATIONS:
# after adding an element {'tulip', 'data science', 'rabbit', 'cheesecake'}
# after removing an element: {'tulip', 'data science', 'cheesecake'}
# DICTIONARY OPERATIONS:
# the dictionary is: {1: 'shifana', 2: 'nahyan', 3: 'aswin'}
# DISPLAYING THE VALUE OF A CORRESPONDING KEY
# shifana
# False
# {1: 'shifana', 2: 'nahyan', 3: 'aswin', 4: 'virat kohli'}
# BOOLEAN OPERATIONS:
# False
# True
# False
# STRING MANIPULATIONS
# the given string is: cheesecake
# the length of the given string is: 10
# the charcter in s[0]: c
# the character in s[-3] a
# ...
